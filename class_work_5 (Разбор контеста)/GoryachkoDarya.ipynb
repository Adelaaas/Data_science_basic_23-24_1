# %%
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-866f0d93-fbc5-4cd8-8295-6c1795f5180c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-866f0d93-fbc5-4cd8-8295-6c1795f5180c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
f = pd.read_csv('weatherHistory.csv')

# %%
f['Temperature (C)'].max()
# Out:
# 39.90555555555555

# %%
# Out:
# 85224

# %%
f['Precip Type'].value_counts()
# Out:
# rain    85224
# snow    10712
# Name: Precip Type, dtype: int64

# %%
f.groupby(['Precip Type']).agg({'Temperature (C)':['mean','max']})
# Out:
#             Temperature (C)
#                        mean        max
# Precip Type
# rain              13.852989  39.905556
# snow              -3.270885   0.000000

# %%
len(f['Temperature (C)']>0)
# Out:
# 96453

# %%
f.groupby(['Formatted Date']).agg({'Temperature (C)':['mean','max']})
# Out:
#                               Temperature (C)
#                                          mean       max
# Formatted Date
# 2006-01-01 00:00:00.000 +0100        0.577778  0.577778
# 2006-01-01 01:00:00.000 +0100        1.161111  1.161111
# 2006-01-01 02:00:00.000 +0100        1.666667  1.666667
# 2006-01-01 03:00:00.000 +0100        1.711111  1.711111
# 2006-01-01 04:00:00.000 +0100        1.183333  1.183333
# ...                                       ...       ...
# 2016-12-31 19:00:00.000 +0100        0.488889  0.488889
# 2016-12-31 20:00:00.000 +0100        0.072222  0.072222
# 2016-12-31 21:00:00.000 +0100       -0.233333 -0.233333
# 2016-12-31 22:00:00.000 +0100       -0.472222 -0.472222
# 2016-12-31 23:00:00.000 +0100       -0.677778 -0.677778
#
# [96429 rows x 2 columns]

# %%
f["Formatted Date"] = pd.to_datetime(f["Formatted Date"], utc=True)
f["Formatted Date"] = f['Formatted Date'].dt.date
f[f["Formatted Date"] == pd.to_datetime('2016-09-09', utc=True).date()]['Temperature (C)'].mean()
# Out:
# 22.730092592592587

# %%
f["Formatted Date"] = pd.to_datetime(f["Formatted Date"], utc=True)
print('ЛЕТО',f[f["Formatted Date"].dt.month.isin([6, 6, 8])].agg({'Wind Speed (km/h)': 'mean', "Temperature (C)": "mean"}))
print('ЗИМА',f[f["Formatted Date"].dt.month.isin([1, 2, 12])].agg({'Wind Speed (km/h)': 'mean', "Temperature (C)": "mean"}))
print('ВЕСНА',f[f["Formatted Date"].dt.month.isin([3, 4, 5])].agg({'Wind Speed (km/h)': 'mean', "Temperature (C)": "mean"}))
print('ОСЕНЬ',f[f["Formatted Date"].dt.month.isin([9, 10, 11])].agg({'Wind Speed (km/h)': 'mean', "Temperature (C)": "mean"}))
# Out:
# ЛЕТО Wind Speed (km/h)     9.281421
# Temperature (C)      21.548203
# dtype: float64
# ЗИМА Wind Speed (km/h)    11.579451
# Temperature (C)       1.516818
# dtype: float64
# ВЕСНА Wind Speed (km/h)    12.083951
# Temperature (C)      12.179874
# dtype: float64
# ОСЕНЬ Wind Speed (km/h)    10.186902
# Temperature (C)      11.803164
# dtype: float64

# %%
f[f["Formatted Date"].dt.month.isin([1, 2, 12])].agg({'Humidity': 'mean'})
# Out:
# Humidity    0.845784
# dtype: float64
