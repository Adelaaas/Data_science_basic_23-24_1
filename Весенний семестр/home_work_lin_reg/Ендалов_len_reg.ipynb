# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
df = pd.read_csv('/content/train.csv')
df.head(30)
# Out:
#     id   MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0    0   2.3859      15.0  3.827160   1.112100      1280.0  2.486989
# 1    1   3.7188      17.0  6.013373   1.054217      1504.0  3.813084
# 2    2   4.7750      27.0  6.535604   1.103175      1061.0  2.464602
# 3    3   2.4138      16.0  3.350203   0.965432      1255.0  2.089286
# 4    4   3.7500      52.0  4.284404   1.069246      1793.0  1.604790
# 5    5   6.8075      26.0  6.764372   1.091787      2147.0  2.703540
# 6    6   2.3654      21.0  4.734884   1.011396      1112.0  2.937247
# 7    7   2.3562      31.0  5.186567   1.154229      1346.0  3.348259
# 8    8   2.2672      23.0  4.640155   1.064302       628.0  1.774461
# 9    9   5.6370      20.0  4.391863   1.053312      1634.0  2.681388
# 10  10   2.6058      26.0  4.295050   1.024242      1667.0  4.287313
# 11  11   6.3942      23.0  7.010324   1.000000      1333.0  2.817259
# 12  12   4.7222      16.0  5.828196   1.067138      1275.0  2.727960
# ...

# %%
print("Кол-во столбцов: ",df.shape[1])
print("Кол-во строк: ",df.shape[0])
print("Пропусков в данных нет; ",df.isnull().sum().sum ())
df.dtypes
# Out:
# Кол-во столбцов:  10
# Кол-во строк:  37137
# Пропусков в данных нет;  0
# id               int64
# MedInc         float64
# HouseAge       float64
# AveRooms       float64
# AveBedrms      float64
# Population     float64
# AveOccup       float64
# Latitude       float64
# Longitude      float64
# MedHouseVal    float64
# dtype: object

# %%
plt.figure(figsize = (8,6))
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.tight_layout()

# %%
#x = df[['AveRooms', 'MedInc', 'HouseAge', 'Latitude', 'AveBedrms', 'Population', 'AveOccup', 'Longitude']]
x = df[['AveRooms']]
y = df[['MedHouseVal']]
'''
plt.scatter(x, y)
plt.xlabel('AveRooms')
plt.ylabel('MedHouseVal')
'''

model = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

print(f'Train dataset size: {X_train.shape}, {y_train.shape}')
print(f'Test dataset size: {X_test.shape}, {y_test.shape}')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.scatter(X_test, y_test)
plt.plot(X_test,y_pred, color='red', linewidth=2);
plt.show()

print('Mean Absolute Error:', mean_absolute_error(y_pred, y_test))
print('Mean Squared Error:', mean_squared_error(y_pred, y_test))
print('R2 score:', r2_score(y_pred, y_test))
# Out:
# Train dataset size: (29709, 1), (29709, 1)
# Test dataset size: (7428, 1), (7428, 1)
# Mean Absolute Error: 0.8471726234045079
# Mean Squared Error: 1.1625430004226005
# R2 score: -6.181660648384289

# %%
print(*model.coef_)
print(*model.intercept_)
#y=a1x1+a2x2+...+anxn+b
# Out:
# [0.34706687]
# 0.2853341973953434

# %%
plt.figure(figsize = (6,8))
sns.boxplot(df['MedInc'], width=0.3)
plt.show()

# %%
plt.figure(figsize = (5,3))
sns.boxplot(df['HouseAge'], width=0.3)
# Out:
# <Axes: ylabel='HouseAge'>

# %%
plt.figure(figsize = (5,7))
sns.boxplot(df['AveRooms'], width=0.3)
# Out:
# <Axes: ylabel='AveRooms'>

# %%
plt.figure(figsize = (5,8))
sns.boxplot(df['AveBedrms'], width=0.1)
# Out:
# <Axes: ylabel='AveBedrms'>

# %%
plt.figure(figsize = (4,6))
sns.boxplot(df['Population'], width=0.2)
# Out:
# <Axes: ylabel='Population'>

# %%
plt.figure(figsize = (4,3))
sns.boxplot(df['AveOccup'], width=0.2)
# Out:
# <Axes: ylabel='AveOccup'>

# %%
plt.figure(figsize = (6,4))
sns.boxplot(df['Latitude'], width=0.2)
# Out:
# <Axes: ylabel='Latitude'>

# %%
plt.figure(figsize = (6,4))
sns.boxplot(df['Longitude'], width=0.2)
# Out:
# <Axes: ylabel='Longitude'>

# %%
plt.figure(figsize = (6,4))
sns.boxplot(df['MedHouseVal'], width=0.2)
# Out:
# <Axes: ylabel='MedHouseVal'>
