# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import seaborn as sns
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/Adelaaas/Data_science_basic_23-24_1/main/work_%D0%B2%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F/train_var_3.csv')
df.head()

fig, ax = plt.subplots(1, 1, figsize=(8, 8), tight_layout=True)

ax.set_title('точечный график')
ax.scatter(df.MinTemp, df.MaxTemp)
ax.set_ylabel('MaxTemp', fontsize=14)
ax.set_xlabel('MinTemp', fontsize=14)
ax.grid(True)

heatmap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad8d40dc7963> in <cell line: 18>()
#      16 ax.grid(True)
#      17
# ---> 18 heatmap
#
# NameError: name 'heatmap' is not defined

# %% [markdown]
# Вывод: на точечном графике видна линнейная прямая зависимость MinTemp и MaxTemp.

# %%
df.head()

plt.figure(figsize=(25,7))

cmap = sns.cubehelix_palette(as_cmap=True, light=.9)

sns.heatmap(df.isna().transpose(), cmap=cmap, cbar_kws={'label': 'Missing Data'})
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Location             0
# MinTemp           1221
# MaxTemp           1031
# Rainfall          2728
# Evaporation      50544
# Sunshine         56175
# WindGustDir       8716
# WindGustSpeed     8661
# WindDir9am        8914
# WindDir3pm        3354
# WindSpeed9am      1519
# WindSpeed3pm      2345
# Humidity9am       2231
# Humidity3pm       3382
# Pressure9am      12635
# Pressure3pm      12602
# Cloud9am         46059
# Cloud3pm         48476
# Temp9am           1533
# Temp3pm           2656
# RainToday            0
# RainTomorrow         0
# dtype: int64

# %% [markdown]
# В столбцах Location, RainToday и RainTommorrow нет пропусков.
# Чаще всего пропуски встречаются в столбцах Evaporation, Sunshine, Cloud9am, Cloud3pm.
# В остальных столбцах примерно одинаковое, не большое кол-во пропусков.

# %%
df.head()

fig, ax = plt.subplots(5, 4, figsize=(16, 16))

sns.boxplot(df.MinTemp, ax = ax[0][0])
ax[0][0].set_title('MinTemp')

sns.boxplot(df.MaxTemp, ax = ax[0][1])
ax[0][1].set_title('MaxTemp')

sns.boxplot(df.MaxTemp, ax = ax[0][2])
ax[0][2].set_title('MaxTemp')

sns.boxplot(df.Rainfall, ax = ax[0][3])
ax[0][3].set_title('Rainfall')

sns.boxplot(df.Evaporation, ax = ax[1][0])
ax[1][0].set_title('Evaporation')

sns.boxplot(df.Sunshine, ax = ax[1][1])
ax[1][1].set_title('Sunshine')

sns.boxplot(df.WindGustSpeed, ax = ax[1][2])
ax[1][2].set_title('WindGustSpeed')

sns.boxplot(df.WindSpeed9am, ax = ax[1][3])
ax[1][3].set_title('WindSpeed9am')

sns.boxplot(df.WindSpeed3pm, ax = ax[2][0])
ax[2][0].set_title('WindSpeed3pm')

sns.boxplot(df.Pressure9am, ax = ax[2][1])
ax[2][1].set_title('Pressure9am')

sns.boxplot(df.Pressure3pm, ax = ax[2][2])
ax[2][2].set_title('Pressure3pm')

sns.boxplot(df.Cloud9am, ax = ax[2][3])
ax[2][3].set_title('Cloud9am')

sns.boxplot(df.Cloud3pm, ax = ax[3][0])
ax[3][0].set_title('Cloud3pm')

sns.boxplot(df.Temp9am, ax = ax[3][1])
ax[3][1].set_title('Temp9am')

sns.boxplot(df.Temp3pm, ax = ax[3][2])
ax[3][2].set_title('Temp3pm')

sns.boxplot(df.RainToday, ax = ax[3][3])
ax[3][3].set_title('RainToday')

sns.boxplot(df.RainTomorrow, ax = ax[4][0])
ax[4][0].set_title('RainTomorrow')
plt.show()

# %%
df.head()
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       Brisbane     13.7     23.6       0.0          5.0       9.6
# 1         Sydney     15.4     21.2      61.2          5.8       2.7
# 2       Richmond     16.8     30.9       1.0          NaN       NaN
# 3  NorfolkIsland     13.9     17.1       0.2          3.8       8.9
# 4        Mildura     16.0     36.1       0.0          6.8      12.9
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0         SSE           24.0        SSW        ESE  ...         65.0
# 1           S           43.0        WSW        SSW  ...         91.0
# 2          NE           35.0        NNW         NE  ...         80.0
# 3          SE           37.0         SE        SSE  ...         56.0
# 4         ENE           33.0        ENE          E  ...         58.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...
